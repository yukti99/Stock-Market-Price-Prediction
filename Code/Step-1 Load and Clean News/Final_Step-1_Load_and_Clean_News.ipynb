# %%
# Importing necessary libraries 
import os
import json
import pandas as pd
import numpy as np
import glob
from IPython import get_ipython


# For data cleaning and visualization
import pandas as pd
import numpy as np
from numpy import array
from datetime import date
from datetime import datetime, timedelta
import pandas_datareader.data as web


# For saving the model
import pickle

# For model Evaluation
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
import math

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# %%
df = pd.read_csv("news_dataset.csv")
df
# Out:
#             id ticker                                              title  \
# 0       221515    NIO  Why Shares of Chinese Electric Car Maker NIO A...
# 1       221516    NIO  NIO only consumer gainer  Workhorse Group amon...
# 2       221517    NIO  NIO leads consumer gainers  Beyond Meat and Ma...
# 3       221518    NIO                  NIO  NVAX among premarket gainers
# 4       221519    NIO                  PLUG  NIO among premarket gainers
# ...        ...    ...                                                ...
# 221508  443024      T                     Crude And Steel Still In Sync
# 221509  443025      T  Forget AT T  This Is The Telecom Stock You Sho...
# 221510  443026      T  Wall Street Exposed   Part 3   How Dividends C...
# 221511  443027      T       Weighing The Week Ahead  It s All About Jobs
# 221512  443028      T  Leap Wireless  LEAP    JPM Note and AT T   T M...
#
#        category                                            content  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'ticker', 'title', 'category', 'content', 'release_date',
#        'provider', 'url', 'article_id'],
#       dtype='object')

# %%
df.ticker.unique()
# Out:
# array(['NIO', 'UBER', 'CTL', 'INTC', 'MSFT', 'MU', 'BLDP', 'FCX', 'EQT',
#        'MRVL', 'TFC', 'MAS', 'KLAC', 'ES', 'LHX', 'NUE', 'CB', 'ALNY',
#        'CLSN', 'TV', 'FMC', 'DNKN', 'WFTLF', 'ASGN', 'CHCI', 'AMSF',
#        'TAOP', 'CECE', 'CTHR', 'CNTFY', 'EDMCQ', 'ECOL', 'EBMT', 'DYNT',
#        'DYSL', 'DXYN', 'DWSN', 'DUSA', 'DXPE', 'DSWL', 'DSG', 'DSPG',
#        'DRAD', 'DORM', 'DMRC', 'DNBF', 'DJCO', 'DISCB', 'DGICA', 'DGICB',
#        'DCIX', 'DCTHD', 'BBQ', 'DAIO', 'CZFC', 'CYTR', 'CWBC', 'CYAN',
#        'CVV', 'CVCO', 'CVCY', 'CVLY', 'BSRR', 'CTWS', 'BVSN', 'HKTVY',
#        'CRZO', 'CSPI', 'CRWS', 'CRAY', 'CRMBQ', 'CRMT', 'CRAI', 'CPSI',
#        'CPSS', 'CPIX', 'TRCB', 'CPHC', 'VIEWF', 'ASFI', 'ARTX', 'CNET',
#        'DXLG', 'CNAF', 'CLRO', 'CLMT', 'CLFD', 'CIDM', 'CIZN', 'PME',
#        'CHOPF', 'CFNB', 'CFFI', 'CENT', 'CFBK', 'CCUR', 'CCRN', 'CCBG',
#        'CBAT', 'CBAN', 'CART', 'CARV', 'CARB', 'CAAS', 'PTVCB', 'BYFC',
# ...

# %%
df = df.drop(columns = ['id', 'ticker', 'content', 'category','provider', 'url', 'article_id'])
df
# Out:
#                                                     title release_date
# 0       Why Shares of Chinese Electric Car Maker NIO A...   2020-01-15
# 1       NIO only consumer gainer  Workhorse Group amon...   2020-01-18
# 2       NIO leads consumer gainers  Beyond Meat and Ma...   2020-01-15
# 3                       NIO  NVAX among premarket gainers   2020-01-15
# 4                       PLUG  NIO among premarket gainers   2020-01-06
# ...                                                   ...          ...
# 221508                     Crude And Steel Still In Sync    2012-10-04
# 221509  Forget AT T  This Is The Telecom Stock You Sho...   2012-05-30
# 221510  Wall Street Exposed   Part 3   How Dividends C...   2012-07-16
# 221511       Weighing The Week Ahead  It s All About Jobs   2012-09-02
# 221512  Leap Wireless  LEAP    JPM Note and AT T   T M...   2011-12-31
#
# [221513 rows x 2 columns]

# %%
df = df.rename({'release_date': 'date', 'title': 'headline'}, axis=1)
df
# Out:
#                                                  headline        date
# 0       Why Shares of Chinese Electric Car Maker NIO A...  2020-01-15
# 1       NIO only consumer gainer  Workhorse Group amon...  2020-01-18
# 2       NIO leads consumer gainers  Beyond Meat and Ma...  2020-01-15
# 3                       NIO  NVAX among premarket gainers  2020-01-15
# 4                       PLUG  NIO among premarket gainers  2020-01-06
# ...                                                   ...         ...
# 221508                     Crude And Steel Still In Sync   2012-10-04
# 221509  Forget AT T  This Is The Telecom Stock You Sho...  2012-05-30
# 221510  Wall Street Exposed   Part 3   How Dividends C...  2012-07-16
# 221511       Weighing The Week Ahead  It s All About Jobs  2012-09-02
# 221512  Leap Wireless  LEAP    JPM Note and AT T   T M...  2011-12-31
#
# [221513 rows x 2 columns]

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(by=['date'], ascending=True)
df
# Out:
#                                                  headline       date
# 6235     Nikkei down 1 4 pct on economy fears  autos drop 2008-10-02
# 105598  FOREX Dollar poised for biggest weekly gain in... 2008-10-03
# 214228  GLOBAL MARKETS Stocks rally on Wells Wachovia ... 2008-10-03
# 220286  GLOBAL MARKETS Stocks hold up after Wells Wach... 2008-10-03
# 220287  GLOBAL MARKETS U S  bailout plan passes  inves... 2008-10-03
# ...                                                   ...        ...
# 220030  Why T Mobile s deal with Sprint could be the w... 2020-02-13
# 209186  6 Low Price to Book Stocks With Great Growth P... 2020-02-13
# 215825  Cisco Systems  CSCO  Q2 Earnings And Revenues ... 2020-02-13
# 220143  Improve Your Retirement Income With These 3 To... 2020-02-13
# 217275  7 Stock Charts To Watch  AVXL  COLL  FSLR  LUN... 2020-02-13
#
# [221513 rows x 2 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#                                                  headline       date
# 0        Nikkei down 1 4 pct on economy fears  autos drop 2008-10-02
# 1       FOREX Dollar poised for biggest weekly gain in... 2008-10-03
# 2       GLOBAL MARKETS Stocks rally on Wells Wachovia ... 2008-10-03
# 3       GLOBAL MARKETS Stocks hold up after Wells Wach... 2008-10-03
# 4       GLOBAL MARKETS U S  bailout plan passes  inves... 2008-10-03
# ...                                                   ...        ...
# 221508  Why T Mobile s deal with Sprint could be the w... 2020-02-13
# 221509  6 Low Price to Book Stocks With Great Growth P... 2020-02-13
# 221510  Cisco Systems  CSCO  Q2 Earnings And Revenues ... 2020-02-13
# 221511  Improve Your Retirement Income With These 3 To... 2020-02-13
# 221512  7 Stock Charts To Watch  AVXL  COLL  FSLR  LUN... 2020-02-13
#
# [221513 rows x 2 columns]

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [headline, date]
# Index: []

# %%
df_missing_percentage = df.isnull().sum()/df.shape[0] *100
df_missing_percentage
# Out:
# headline    0.0
# date        0.0
# dtype: float64

# %%
# dropping NaN values
df = df.dropna()
df = df.reset_index(drop=True)
df
# Out:
#                                                  headline       date
# 0        Nikkei down 1 4 pct on economy fears  autos drop 2008-10-02
# 1       FOREX Dollar poised for biggest weekly gain in... 2008-10-03
# 2       GLOBAL MARKETS Stocks rally on Wells Wachovia ... 2008-10-03
# 3       GLOBAL MARKETS Stocks hold up after Wells Wach... 2008-10-03
# 4       GLOBAL MARKETS U S  bailout plan passes  inves... 2008-10-03
# ...                                                   ...        ...
# 221508  Why T Mobile s deal with Sprint could be the w... 2020-02-13
# 221509  6 Low Price to Book Stocks With Great Growth P... 2020-02-13
# 221510  Cisco Systems  CSCO  Q2 Earnings And Revenues ... 2020-02-13
# 221511  Improve Your Retirement Income With These 3 To... 2020-02-13
# 221512  7 Stock Charts To Watch  AVXL  COLL  FSLR  LUN... 2020-02-13
#
# [221513 rows x 2 columns]

# %%
df.shape
# Out:
# (221513, 2)

# %%
# Cleaning the data
#df1['headline'] = df1['headline'].replace("[^a-zA-Z]"," ",regex=True)
#df1

# %%
df.to_csv("FinalData/news_headlines.csv")
